# %% [markdown]
# # AWS re:Invent 2018 AIM350
#
# ## Apache MXNet training script launcher

# %%
import sagemaker
from sagemaker.mxnet import MXNet
from sagemaker import get_execution_role

import os

# %% [markdown]
# ### Define S3 bucket and prefix for datasets and models

# %%
s3_bucket = 'mh-s3-icn-sagemaker'
s3_prefix = 'reinvent-aim350/mxnet'

s3_data_prefix = '{}/data'.format(s3_prefix)
output_s3 = 's3://{}/{}/models/'.format(s3_bucket, s3_prefix)
code_location_s3 = 's3://{}/{}/codes'.format(s3_bucket, s3_prefix)

# %% [markdown]
# ### Define sagemaker Sessoin and Role

# %%
sagemaker_session = sagemaker.Session()
role = get_execution_role()

# %% [markdown]
# ### Upload training and testing files to S3 bucket

# %%
from keras.datasets import mnist

data_filename = 'mnist.npz'
mnist_data = mnist.load_data(path=data_filename)
# Out:
# Using MXNet backend
# Using MXNet backend
# Using MXNet backend

# %%
train_s3 = sagemaker_session.upload_data(path=os.path.expanduser('~/.keras/datasets/'),
                                         bucket=s3_bucket,
                                         key_prefix=s3_data_prefix
                                        )

inputs = {'train':train_s3}

print(output_s3)
print(inputs)
# Out:
# s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/models/
# {'train': 's3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/data'}
# s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/models/
# {'train': 's3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/data'}
# s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/models/
# {'train': 's3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/data'}

# %% [markdown]
# ### Define Hyperparameters

# %%
hyperparameters = {'epochs': 1}

# %% [markdown]
# ### Define SageMaker TensorFlow Estimator
#
# There are some arguments to be noted;
#
# * **script_mode (bool)**: If set to True will the estimator will use the Script Mode containers (default: False). This will be ignored if py_version is set to 'py3'.
#
# * **model_dir (str)**: S3 location where the checkpoint data and models can be exported to during training (default: None). If not specified a default S3 URI will be generated. It will be passed in the training script as one of the command line arguments.

# %%
estimator = MXNet(entry_point='mxnet_keras_script_mode.py',
                       source_dir='./mxnet-src',
                       role=role,
                       train_instance_count=1,
                       train_instance_type='ml.c4.2xlarge',
                       hyperparameters=hyperparameters,
                       framework_version='1.3',
                       py_version='py3',
                       output_path=output_s3,
                       code_location=code_location_s3,
                       base_job_name='mxnet-scriptmode-mnist'
#                        requirements_file='./requirements.txt'
                      )

# %% [markdown]
# Amazon SageMaker runs the specified MXNet training script using the below command:
#
# ```
# /usr/bin/python -m mxnet_keras_script_mode --epochs 1
# ```

# %%
# %%time

estimator.fit(inputs)
# Out:
# INFO:sagemaker:Creating training-job with name: mxnet-scriptmode-mnist-2018-11-24-13-52-06-503
# INFO:sagemaker:Creating training-job with name: mxnet-scriptmode-mnist-2018-11-24-13-52-06-503
# INFO:sagemaker:Creating training-job with name: mxnet-scriptmode-mnist-2018-11-24-13-52-06-503
# 2018-11-24 13:52:07 Starting - Starting the training job.2018-11-24 13:52:07 Starting - Starting the training job.2018-11-24 13:52:07 Starting - Starting the training job.......
# 2018-11-24 13:52:11 Starting - Launching requested ML instances.
# 2018-11-24 13:52:11 Starting - Launching requested ML instances.
# 2018-11-24 13:52:11 Starting - Launching requested ML instances................
# 2018-11-24 13:53:09 Starting - Preparing the instances for training.
# 2018-11-24 13:53:09 Starting - Preparing the instances for training.
# 2018-11-24 13:53:09 Starting - Preparing the instances for training.......
# 2018-11-24 13:54:05 Downloading - Downloading input data.
# 2018-11-24 13:54:05 Downloading - Downloading input data.
# 2018-11-24 13:54:05 Downloading - Downloading input data....
# 2018-11-24 13:54:17,234 sagemaker-containers INFO     Imported framework sagemaker_mxnet_container.training
# 2018-11-24 13:54:17,236 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-24 13:54:17,249 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"mxnet-scriptmode-mnist-2018-11-24-13-52-06-503","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz","module_name":"mxnet_keras_script_mode","network_interface_name":"ethwe","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"},"user_entry_point":"mxnet_keras_script_mode.py"}', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_USER_ARGS': '["--epochs","1"]', 'SM_HPS': '{"epochs":1}', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_HP_EPOCHS': '1', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_INPUT_DATA_CONFIG': '{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_NUM_GPUS': '0', 'SM_CHANNEL_TRAIN': '/opt/ml/input/data/train', 'SM_CURRENT_HOST': 'algo-1', 'SM_HOSTS': '["algo-1"]', 'SM_MODULE_DIR': 's3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz', 'SM_LOG_LEVEL': '20', 'SM_MODULE_NAME': 'mxnet_keras_script_mode', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}', 'SM_NETWORK_INTERFACE_NAME': 'ethwe', 'SM_INPUT_CO
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Module mxnet_keras_script_mode does not provide a setup.py.
# Generating setup.py
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Generating setup.cfg
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Generating MANIFEST.in
# 2018-11-24 13:54:17,623 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install -U .
# Processing /opt/ml/code
# Building wheels for collected packages: mxnet-keras-script-mode
#   Running setup.py bdist_wheel for mxnet-keras-script-mode: started
#   Running setup.py bdist_wheel for mxnet-keras-script-mode: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2w5iky71/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mxnet-keras-script-mode
# Installing collected packages: mxnet-keras-script-mode
# Successfully installed mxnet-keras-script-mode-1.0.0
# 2018-11-24 13:54:19,194 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-24 13:54:19,208 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "hyperparameters": {
#         "epochs": 1
#     },
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "module_dir": "s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz",
#     "current_host": "algo-1",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "num_cpus": 8,
#     "user_entry_point": "mxnet_keras_script_mode.py",
#     "additional_framework_parameters": {},
#     "module_name": "mxnet_keras_script_mode",
#     "network_interface_name": "ethwe",
#     "num_gpus": 0,
#     "output_dir": "/opt/ml/output",
#     "job_name": "mxnet-scriptmode-mnist-2018-11-24-13-52-06-503",
#     "hosts": [
#         "algo-1"
#     ],
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "output_data_dir": "/opt/ml/output/data",
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     }
# }
#
# Environment variables:
#
# SM_FRAMEWORK_PARAMS={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_USER_ARGS=["--epochs","1"]
# SM_HPS={"epochs":1}
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_HP_EPOCHS=1
# SM_OUTPUT_DIR=/opt/ml/output
# SM_CHANNELS=["train"]
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_NUM_GPUS=0
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CURRENT_HOST=algo-1
# SM_HOSTS=["algo-1"]
# SM_MODULE_DIR=s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz
# SM_LOG_LEVEL=20
# SM_MODULE_NAME=mxnet_keras_script_mode
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}
# SM_NETWORK_INTERFACE_NAME=ethwe
# PYTHONPATH=/usr/local/bin:/usr/lib/python35.zip:/usr/lib/python3.5:/usr/lib/python3.5/plat-x86_64-linux-gnu:/usr/lib/python3.5/lib-dynload:/usr/local/lib/python3.5/dist-packages:/usr/lib/python3/dist-packages
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_MODEL_DIR=/opt/ml/model
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"mxnet-scriptmode-mnist-2018-11-24-13-52-06-503","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz","module_name":"mxnet_keras_script_mode","network_interface_name":"ethwe","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"},"user_entry_point":"mxnet_keras_script_mode.py"}
# SM_NUM_CPUS=8
# SM_USER_ENTRY_POINT=mxnet_keras_script_mode.py
#
# Invoking script with the following command:
#
# /usr/bin/python -m mxnet_keras_script_mode --epochs 1
#
#
# Using MXNet backend
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# /usr/local/lib/python3.5/dist-packages/keras/backend/mxnet_backend.py:89: UserWarning: MXNet Backend performs best with `channels_first` format. Using `channels_last` will significantly reduce performance due to the Transpose operations. For performance improvement, please use this API`keras.utils.to_channels_first(x_input)`to transform `channels_last` data to `channels_first` format and also please change the `image_data_format` in `keras.json` to `channels_first`.Note: `x_input` is a Numpy tensor or a list of Numpy tensorRefer to: https://github.com/awslabs/keras-apache-mxnet/tree/master/docs/mxnet_backend/performance_guide.md
#   train_symbol = func(*args, **kwargs)
# /usr/local/lib/python3.5/dist-packages/keras/backend/mxnet_backend.py:92: UserWarning: MXNet Backend performs best with `channels_first` format. Using `channels_last` will significantly reduce performance due to the Transpose operations. For performance improvement, please use this API`keras.utils.to_channels_first(x_input)`to transform `channels_last` data to `channels_first` format and also please change the `image_data_format` in `keras.json` to `channels_first`.Note: `x_input` is a Numpy tensor or a list of Numpy tensorRefer to: https://github.com/awslabs/keras-apache-mxnet/tree/master/docs/mxnet_backend/performance_guide.md
#   test_symbol = func(*args, **kwargs)
# /usr/local/lib/python3.5/dist-packages/keras/losses.py:139: UserWarning: MXNet Backend: If you are using a custom loss function and use slice operator in custom loss function, please set the **_keras_shape** attribute of the loss tensor explicitly.
#
# Without this workaround, you may encounter shape mismatch errors in the broadcast operations.
#
# For more details - https://github.com/awslabs/keras-apache-mxnet/issues/120
#
#
#   warnings.warn('MXNet Backend: If you are using a custom loss function and use slice operator in custom '
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# /usr/local/lib/python3.5/dist-packages/mxnet/module/bucketing_module.py:408: UserWarning: Optimizer created manually outside Module but rescale_grad is not normalized to 1.0/batch_size/num_workers (1.0 vs. 0.0078125). Is this intended?
#   force_init=force_init)
# 2018-11-24 13:54:17,234 sagemaker-containers INFO     Imported framework sagemaker_mxnet_container.training
# 2018-11-24 13:54:17,236 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-24 13:54:17,249 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"mxnet-scriptmode-mnist-2018-11-24-13-52-06-503","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz","module_name":"mxnet_keras_script_mode","network_interface_name":"ethwe","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"},"user_entry_point":"mxnet_keras_script_mode.py"}', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_USER_ARGS': '["--epochs","1"]', 'SM_HPS': '{"epochs":1}', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_HP_EPOCHS': '1', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_INPUT_DATA_CONFIG': '{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_NUM_GPUS': '0', 'SM_CHANNEL_TRAIN': '/opt/ml/input/data/train', 'SM_CURRENT_HOST': 'algo-1', 'SM_HOSTS': '["algo-1"]', 'SM_MODULE_DIR': 's3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz', 'SM_LOG_LEVEL': '20', 'SM_MODULE_NAME': 'mxnet_keras_script_mode', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}', 'SM_NETWORK_INTERFACE_NAME': 'ethwe', 'SM_INPUT_CO
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Module mxnet_keras_script_mode does not provide a setup.py.
# Generating setup.py
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Generating setup.cfg
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Generating MANIFEST.in
# 2018-11-24 13:54:17,623 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install -U .
# Processing /opt/ml/code
# Building wheels for collected packages: mxnet-keras-script-mode
#   Running setup.py bdist_wheel for mxnet-keras-script-mode: started
#   Running setup.py bdist_wheel for mxnet-keras-script-mode: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2w5iky71/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mxnet-keras-script-mode
# Installing collected packages: mxnet-keras-script-mode
# Successfully installed mxnet-keras-script-mode-1.0.0
# 2018-11-24 13:54:19,194 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-24 13:54:19,208 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "hyperparameters": {
#         "epochs": 1
#     },
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "module_dir": "s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz",
#     "current_host": "algo-1",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "num_cpus": 8,
#     "user_entry_point": "mxnet_keras_script_mode.py",
#     "additional_framework_parameters": {},
#     "module_name": "mxnet_keras_script_mode",
#     "network_interface_name": "ethwe",
#     "num_gpus": 0,
#     "output_dir": "/opt/ml/output",
#     "job_name": "mxnet-scriptmode-mnist-2018-11-24-13-52-06-503",
#     "hosts": [
#         "algo-1"
#     ],
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "output_data_dir": "/opt/ml/output/data",
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     }
# }
#
# Environment variables:
#
# SM_FRAMEWORK_PARAMS={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_USER_ARGS=["--epochs","1"]
# SM_HPS={"epochs":1}
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_HP_EPOCHS=1
# SM_OUTPUT_DIR=/opt/ml/output
# SM_CHANNELS=["train"]
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_NUM_GPUS=0
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CURRENT_HOST=algo-1
# SM_HOSTS=["algo-1"]
# SM_MODULE_DIR=s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz
# SM_LOG_LEVEL=20
# SM_MODULE_NAME=mxnet_keras_script_mode
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}
# SM_NETWORK_INTERFACE_NAME=ethwe
# PYTHONPATH=/usr/local/bin:/usr/lib/python35.zip:/usr/lib/python3.5:/usr/lib/python3.5/plat-x86_64-linux-gnu:/usr/lib/python3.5/lib-dynload:/usr/local/lib/python3.5/dist-packages:/usr/lib/python3/dist-packages
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_MODEL_DIR=/opt/ml/model
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"mxnet-scriptmode-mnist-2018-11-24-13-52-06-503","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz","module_name":"mxnet_keras_script_mode","network_interface_name":"ethwe","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"},"user_entry_point":"mxnet_keras_script_mode.py"}
# SM_NUM_CPUS=8
# SM_USER_ENTRY_POINT=mxnet_keras_script_mode.py
#
# Invoking script with the following command:
#
# /usr/bin/python -m mxnet_keras_script_mode --epochs 1
#
#
# Using MXNet backend
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# /usr/local/lib/python3.5/dist-packages/keras/backend/mxnet_backend.py:89: UserWarning: MXNet Backend performs best with `channels_first` format. Using `channels_last` will significantly reduce performance due to the Transpose operations. For performance improvement, please use this API`keras.utils.to_channels_first(x_input)`to transform `channels_last` data to `channels_first` format and also please change the `image_data_format` in `keras.json` to `channels_first`.Note: `x_input` is a Numpy tensor or a list of Numpy tensorRefer to: https://github.com/awslabs/keras-apache-mxnet/tree/master/docs/mxnet_backend/performance_guide.md
#   train_symbol = func(*args, **kwargs)
# /usr/local/lib/python3.5/dist-packages/keras/backend/mxnet_backend.py:92: UserWarning: MXNet Backend performs best with `channels_first` format. Using `channels_last` will significantly reduce performance due to the Transpose operations. For performance improvement, please use this API`keras.utils.to_channels_first(x_input)`to transform `channels_last` data to `channels_first` format and also please change the `image_data_format` in `keras.json` to `channels_first`.Note: `x_input` is a Numpy tensor or a list of Numpy tensorRefer to: https://github.com/awslabs/keras-apache-mxnet/tree/master/docs/mxnet_backend/performance_guide.md
#   test_symbol = func(*args, **kwargs)
# /usr/local/lib/python3.5/dist-packages/keras/losses.py:139: UserWarning: MXNet Backend: If you are using a custom loss function and use slice operator in custom loss function, please set the **_keras_shape** attribute of the loss tensor explicitly.
#
# Without this workaround, you may encounter shape mismatch errors in the broadcast operations.
#
# For more details - https://github.com/awslabs/keras-apache-mxnet/issues/120
#
#
#   warnings.warn('MXNet Backend: If you are using a custom loss function and use slice operator in custom '
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# /usr/local/lib/python3.5/dist-packages/mxnet/module/bucketing_module.py:408: UserWarning: Optimizer created manually outside Module but rescale_grad is not normalized to 1.0/batch_size/num_workers (1.0 vs. 0.0078125). Is this intended?
#   force_init=force_init)
# 2018-11-24 13:54:17,234 sagemaker-containers INFO     Imported framework sagemaker_mxnet_container.training
# 2018-11-24 13:54:17,236 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-24 13:54:17,249 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"mxnet-scriptmode-mnist-2018-11-24-13-52-06-503","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz","module_name":"mxnet_keras_script_mode","network_interface_name":"ethwe","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"},"user_entry_point":"mxnet_keras_script_mode.py"}', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_USER_ARGS': '["--epochs","1"]', 'SM_HPS': '{"epochs":1}', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_HP_EPOCHS': '1', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_INPUT_DATA_CONFIG': '{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_NUM_GPUS': '0', 'SM_CHANNEL_TRAIN': '/opt/ml/input/data/train', 'SM_CURRENT_HOST': 'algo-1', 'SM_HOSTS': '["algo-1"]', 'SM_MODULE_DIR': 's3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz', 'SM_LOG_LEVEL': '20', 'SM_MODULE_NAME': 'mxnet_keras_script_mode', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}', 'SM_NETWORK_INTERFACE_NAME': 'ethwe', 'SM_INPUT_CO
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Module mxnet_keras_script_mode does not provide a setup.py.
# Generating setup.py
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Generating setup.cfg
# 2018-11-24 13:54:17,622 sagemaker-containers INFO     Generating MANIFEST.in
# 2018-11-24 13:54:17,623 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install -U .
# Processing /opt/ml/code
# Building wheels for collected packages: mxnet-keras-script-mode
#   Running setup.py bdist_wheel for mxnet-keras-script-mode: started
#   Running setup.py bdist_wheel for mxnet-keras-script-mode: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2w5iky71/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# Successfully built mxnet-keras-script-mode
# Installing collected packages: mxnet-keras-script-mode
# Successfully installed mxnet-keras-script-mode-1.0.0
# 2018-11-24 13:54:19,194 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-11-24 13:54:19,208 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "hyperparameters": {
#         "epochs": 1
#     },
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "module_dir": "s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz",
#     "current_host": "algo-1",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "num_cpus": 8,
#     "user_entry_point": "mxnet_keras_script_mode.py",
#     "additional_framework_parameters": {},
#     "module_name": "mxnet_keras_script_mode",
#     "network_interface_name": "ethwe",
#     "num_gpus": 0,
#     "output_dir": "/opt/ml/output",
#     "job_name": "mxnet-scriptmode-mnist-2018-11-24-13-52-06-503",
#     "hosts": [
#         "algo-1"
#     ],
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "output_data_dir": "/opt/ml/output/data",
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     }
# }
#
# Environment variables:
#
# SM_FRAMEWORK_PARAMS={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_USER_ARGS=["--epochs","1"]
# SM_HPS={"epochs":1}
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_HP_EPOCHS=1
# SM_OUTPUT_DIR=/opt/ml/output
# SM_CHANNELS=["train"]
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_NUM_GPUS=0
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CURRENT_HOST=algo-1
# SM_HOSTS=["algo-1"]
# SM_MODULE_DIR=s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz
# SM_LOG_LEVEL=20
# SM_MODULE_NAME=mxnet_keras_script_mode
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}
# SM_NETWORK_INTERFACE_NAME=ethwe
# PYTHONPATH=/usr/local/bin:/usr/lib/python35.zip:/usr/lib/python3.5:/usr/lib/python3.5/plat-x86_64-linux-gnu:/usr/lib/python3.5/lib-dynload:/usr/local/lib/python3.5/dist-packages:/usr/lib/python3/dist-packages
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_MODEL_DIR=/opt/ml/model
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"mxnet-scriptmode-mnist-2018-11-24-13-52-06-503","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz","module_name":"mxnet_keras_script_mode","network_interface_name":"ethwe","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"},"user_entry_point":"mxnet_keras_script_mode.py"}
# SM_NUM_CPUS=8
# SM_USER_ENTRY_POINT=mxnet_keras_script_mode.py
#
# Invoking script with the following command:
#
# /usr/bin/python -m mxnet_keras_script_mode --epochs 1
#
#
# Using MXNet backend
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# /usr/local/lib/python3.5/dist-packages/keras/backend/mxnet_backend.py:89: UserWarning: MXNet Backend performs best with `channels_first` format. Using `channels_last` will significantly reduce performance due to the Transpose operations. For performance improvement, please use this API`keras.utils.to_channels_first(x_input)`to transform `channels_last` data to `channels_first` format and also please change the `image_data_format` in `keras.json` to `channels_first`.Note: `x_input` is a Numpy tensor or a list of Numpy tensorRefer to: https://github.com/awslabs/keras-apache-mxnet/tree/master/docs/mxnet_backend/performance_guide.md
#   train_symbol = func(*args, **kwargs)
# /usr/local/lib/python3.5/dist-packages/keras/backend/mxnet_backend.py:92: UserWarning: MXNet Backend performs best with `channels_first` format. Using `channels_last` will significantly reduce performance due to the Transpose operations. For performance improvement, please use this API`keras.utils.to_channels_first(x_input)`to transform `channels_last` data to `channels_first` format and also please change the `image_data_format` in `keras.json` to `channels_first`.Note: `x_input` is a Numpy tensor or a list of Numpy tensorRefer to: https://github.com/awslabs/keras-apache-mxnet/tree/master/docs/mxnet_backend/performance_guide.md
#   test_symbol = func(*args, **kwargs)
# /usr/local/lib/python3.5/dist-packages/keras/losses.py:139: UserWarning: MXNet Backend: If you are using a custom loss function and use slice operator in custom loss function, please set the **_keras_shape** attribute of the loss tensor explicitly.
#
# Without this workaround, you may encounter shape mismatch errors in the broadcast operations.
#
# For more details - https://github.com/awslabs/keras-apache-mxnet/issues/120
#
#
#   warnings.warn('MXNet Backend: If you are using a custom loss function and use slice operator in custom '
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# /usr/local/lib/python3.5/dist-packages/mxnet/module/bucketing_module.py:408: UserWarning: Optimizer created manually outside Module but rescale_grad is not normalized to 1.0/batch_size/num_workers (1.0 vs. 0.0078125). Is this intended?
#   force_init=force_init)
# 2018-11-24 13:54:16 Training - Training image download completed. Training in progress.
# 2018-11-24 13:54:16 Training - Training image download completed. Training in progress.
# 2018-11-24 13:54:16 Training - Training image download completed. Training in progress.
# 2018-11-24 13:57:39 Uploading - Uploading generated training model - 184s - loss: 0.6310 - acc: 0.8232 - val_loss: 0.2643 - val_acc: 0.9289
#
# 2018-11-24 13:57:39 Uploading - Uploading generated training model - 184s - loss: 0.6310 - acc: 0.8232 - val_loss: 0.2643 - val_acc: 0.9289
#
# 2018-11-24 13:57:39 Uploading - Uploading generated training model - 184s - loss: 0.6310 - acc: 0.8232 - val_loss: 0.2643 - val_acc: 0.9289
# Test loss: 0.2642908645808697
# Test accuracy: 0.9289
# Saving model in MXNet format
# MXNet Backend: Successfully exported the model as MXNet model!
# MXNet symbol file -  /opt/ml/model/model-symbol.json
# MXNet params file -  /opt/ml/model/model-0000.params
#
#
# Model input data_names and data_shapes are:
# data_names :  ['/conv2d_1_input1']
# data_shapes :  [DataDesc[/conv2d_1_input1,(128, 28, 28, 1),float32,NCHW]]
#
#
# Note: In the above data_shapes, the first dimension represent the batch_size used for model training.
# You can change the batch_size for binding the module based on your inference batch_size.
# Exporting model to ONNX format
# 2018-11-24 13:57:36,420 sagemaker-containers INFO     Reporting training SUCCESS
# Test loss: 0.2642908645808697
# Test accuracy: 0.9289
# Saving model in MXNet format
# MXNet Backend: Successfully exported the model as MXNet model!
# MXNet symbol file -  /opt/ml/model/model-symbol.json
# MXNet params file -  /opt/ml/model/model-0000.params
#
#
# Model input data_names and data_shapes are:
# data_names :  ['/conv2d_1_input1']
# data_shapes :  [DataDesc[/conv2d_1_input1,(128, 28, 28, 1),float32,NCHW]]
#
#
# Note: In the above data_shapes, the first dimension represent the batch_size used for model training.
# You can change the batch_size for binding the module based on your inference batch_size.
# Exporting model to ONNX format
# 2018-11-24 13:57:36,420 sagemaker-containers INFO     Reporting training SUCCESS
# Test loss: 0.2642908645808697
# Test accuracy: 0.9289
# Saving model in MXNet format
# MXNet Backend: Successfully exported the model as MXNet model!
# MXNet symbol file -  /opt/ml/model/model-symbol.json
# MXNet params file -  /opt/ml/model/model-0000.params
#
#
# Model input data_names and data_shapes are:
# data_names :  ['/conv2d_1_input1']
# data_shapes :  [DataDesc[/conv2d_1_input1,(128, 28, 28, 1),float32,NCHW]]
#
#
# Note: In the above data_shapes, the first dimension represent the batch_size used for model training.
# You can change the batch_size for binding the module based on your inference batch_size.
# Exporting model to ONNX format
# 2018-11-24 13:57:36,420 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2018-11-24 13:57:44 Completed - Training job completed
#
# 2018-11-24 13:57:44 Completed - Training job completed
#
# 2018-11-24 13:57:44 Completed - Training job completed
# Billable seconds: 220
# CPU times: user 927 ms, sys: 52.3 ms, total: 980 ms
# Wall time: 6min 14s
# Billable seconds: 220
# CPU times: user 927 ms, sys: 52.3 ms, total: 980 ms
# Wall time: 6min 14s
# Billable seconds: 220
# CPU times: user 927 ms, sys: 52.3 ms, total: 980 ms
# Wall time: 6min 14s

# %%
# !aws s3 ls --recursive s3://mh-s3-icn-sagemaker/reinvent-aim350/mxnet
# Out:
# 2018-11-24 13:52:07    4422105 reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz
# 2018-11-24 13:52:07   11490434 reinvent-aim350/mxnet/data/mnist.npz
# 2018-11-24 13:57:43    8865395 reinvent-aim350/mxnet/models/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/output/model.tar.gz
# 2018-11-24 13:52:07    4422105 reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz
# 2018-11-24 13:52:07   11490434 reinvent-aim350/mxnet/data/mnist.npz
# 2018-11-24 13:57:43    8865395 reinvent-aim350/mxnet/models/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/output/model.tar.gz
# 2018-11-24 13:52:07    4422105 reinvent-aim350/mxnet/codes/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/source/sourcedir.tar.gz
# 2018-11-24 13:52:07   11490434 reinvent-aim350/mxnet/data/mnist.npz
# 2018-11-24 13:57:43    8865395 reinvent-aim350/mxnet/models/mxnet-scriptmode-mnist-2018-11-24-13-52-06-503/output/model.tar.gz

# %%
# estimator?

# %%
# sagemaker.estimator.Framework?

# %% [markdown]
# ```
# python mxnet_keras_script_mode.py --epochs 1 --train ~/.keras/datasets
# ```
